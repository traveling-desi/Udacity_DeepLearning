# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
int_words
# Out:
# [5236,
#  3083,
#  11,
#  5,
#  194,
#  1,
#  3133,
#  45,
#  58,
#  155,
#  127,
#  741,
#  476,
#  10612,
#  133,
#  0,
#  27637,
#  1,
#  0,
#  102,
#  854,
#  2,
#  0,
#  15117,
#  61638,
#  1,
#  0,
#  150,
#  854,
#  3584,
#  0,
#  194,
#  10,
#  190,
#  58,
#  4,
#  5,
#  10753,
#  214,
#  6,
#  1324,
#  104,
#  454,
#  19,
#  58,
#  2731,
#  362,
#  6,
#  3672,
#  0,
#  708,
#  1,
#  371,
#  26,
#  40,
#  36,
#  53,
#  539,
#  97,
#  11,
#  5,
#  1424,
#  2759,
#  18,
#  567,
#  686,
#  7096,
#  0,
#  247,
#  5236,
#  10,
#  1052,
#  27,
#  0,
#  320,
#  248,
#  45093,
#  2879,
#  792,
#  186,
#  5236,
#  11,
#  5,
#  200,
#  602,
#  10,
#  0,
#  1136,
#  19,
#  2621,
#  25,
#  9010,
#  2,
#  279,
#  31,
#  4149,
#  141,
#  59,
#  25,
#  6444,
#  4190,
#  1,
#  153,
#  32,
#  362,
#  5236,
#  36,
#  1137,
#  6,
#  447,
#  345,
#  1818,
#  19,
#  4869,
#  0,
#  6774,
#  1,
#  7583,
#  1774,
#  566,
#  0,
#  93,
#  0,
#  247,
#  11118,
#  11,
#  51,
#  7096,
#  89,
#  26,
#  270,
#  37,
#  5949,
#  4868,
#  20371,
#  28,
#  55086,
#  41,
#  317,
#  5,
#  25902,
#  527,
#  7583,
#  371,
#  4,
#  258,
#  1,
#  153,
#  25,
#  1206,
#  11,
#  7583,
#  200,
#  1580,
#  2,
#  15309,
#  332,
#  1774,
#  7096,
#  4869,
#  345,
#  764,
#  160,
#  406,
#  5705,
#  756,
#  1,
#  4107,
#  1132,
#  4333,
#  1536,
#  2,
#  567,
#  8129,
#  98,
#  5236,
#  10,
#  51,
#  1407,
#  686,
#  18,
#  153,
#  26,
#  10,
#  155,
#  7096,
#  36,
#  2033,
#  1424,
#  8195,
#  1,
#  153,
#  46,
#  694,
#  6,
#  31,
#  5,
#  4160,
#  246,
#  371,
#  76,
#  948,
#  78,
#  310,
#  30,
#  4790,
#  371,
#  507,
#  139,
#  2313,
#  3560,
#  364,
#  23,
#  1821,
#  6,
#  1902,
#  59,
#  10,
#  36,
#  8417,
#  78,
#  310,
#  5,
#  246,
#  371,
#  507,
#  31,
#  753,
#  78,
#  1732,
#  2,
#  8058,
#  24561,
#  2,
#  275,
#  1693,
#  19,
#  151,
#  1033,
#  95,
#  225,
#  371,
#  17,
#  1815,
#  24,
#  4790,
#  1556,
#  51,
#  8139,
#  1466,
#  24561,
#  2,
#  12815,
#  4,
#  6144,
#  19,
#  4187,
#  21167,
#  2428,
#  39,
#  16457,
#  2,
#  7244,
#  861,
#  1,
#  1194,
#  10248,
#  2514,
#  28,
#  15134,
#  187,
#  2,
#  48,
#  1123,
#  912,
#  6,
#  1049,
#  467,
#  12314,
#  7096,
#  133,
#  0,
#  0,
#  11118,
#  3061,
#  2,
#  12061,
#  734,
#  4790,
#  6618,
#  4,
#  14690,
#  27,
#  450,
#  485,
#  24561,
#  198,
#  295,
#  948,
#  4,
#  20240,
#  20516,
#  1,
#  57369,
#  300,
#  6,
#  24561,
#  20516,
#  16482,
#  0,
#  30446,
#  1,
#  0,
#  93,
#  44,
#  3837,
#  2,
#  53740,
#  2,
#  3814,
#  0,
#  3413,
#  1,
#  0,
#  1776,
#  187,
#  1,
#  0,
#  626,
#  0,
#  13194,
#  1,
#  3,
#  21,
#  90,
#  122,
#  284,
#  25,
#  243,
#  232,
#  6,
#  31,
#  437,
#  26441,
#  1,
#  173,
#  5236,
#  7716,
#  2537,
#  4,
#  29,
#  95,
#  1,
#  289,
#  602,
#  4308,
#  19,
#  0,
#  13194,
#  16482,
#  49,
#  187,
#  117,
#  46,
#  359,
#  19,
#  0,
#  384,
#  242,
#  96,
#  31,
#  5234,
#  34,
#  331,
#  2723,
#  18,
#  0,
#  838,
#  1378,
#  27,
#  32,
#  8786,
#  46,
#  6483,
#  34,
#  3243,
#  0,
#  27637,
#  28,
#  551,
#  44235,
#  39,
#  30,
#  127,
#  57283,
#  435,
#  84,
#  0,
#  64,
#  1,
#  0,
#  102,
#  462,
#  83,
#  2,
#  25,
#  232,
#  18,
#  47,
#  11,
#  26441,
#  1,
#  173,
#  5236,
#  4,
#  0,
#  173,
#  839,
#  0,
#  45,
#  6,
#  89,
#  0,
#  194,
#  6,
#  1015,
#  1043,
#  42,
#  69,
#  4868,
#  17,
#  936,
#  14977,
#  4575,
#  164,
#  4,
#  29,
#  42405,
#  11838,
#  22966,
#  259,
#  1225,
#  63378,
#  3,
#  22,
#  7,
#  16,
#  99,
#  35,
#  628,
#  0,
#  2664,
#  63,
#  371,
#  33,
#  48,
#  75,
#  93,
#  687,
#  14802,
#  4045,
#  28,
#  818,
#  917,
#  11,
#  101,
#  4,
#  11118,
#  2537,
#  362,
#  5,
#  6055,
#  2,
#  662,
#  4,
#  0,
#  63,
#  701,
#  435,
#  40,
#  4220,
#  1289,
#  19,
#  35,
#  10,
#  30,
#  4790,
#  2,
#  94,
#  25,
#  49,
#  29,
#  5228,
#  4,
#  3,
#  22,
#  8,
#  16,
#  4,
#  0,
#  5352,
#  1,
#  0,
#  150,
#  854,
#  467,
#  12314,
#  334,
#  30,
#  17368,
#  2434,
#  200,
#  1293,
#  141,
#  12314,
#  215,
#  37,
#  89,
#  0,
#  247,
#  5236,
#  55,
#  116,
#  7096,
#  38,
#  1206,
#  32,
#  197,
#  11,
#  0,
#  45,
#  181,
#  4790,
#  529,
#  2,
#  12314,
#  11,
#  0,
#  1834,
#  1,
#  1913,
#  5236,
#  41,
#  34,
#  32,
#  228,
#  75,
#  4790,
#  435,
#  733,
#  2400,
#  2,
#  0,
#  194,
#  17,
#  86,
#  1073,
#  11,
#  30,
#  14054,
#  30503,
#  18,
#  0,
#  12101,
#  59997,
#  34,
#  50,
#  2419,
#  616,
#  4,
#  0,
#  150,
#  854,
#  0,
#  45,
#  567,
#  8724,
#  4790,
#  2938,
#  1034,
#  14619,
#  26,
#  10,
#  636,
#  359,
#  19,
#  26,
#  5396,
#  154,
#  191,
#  2938,
#  1034,
#  14619,
#  334,
#  153,
#  10,
#  917,
#  4,
#  3,
#  12,
#  20,
#  7,
#  19,
#  0,
#  194,
#  4790,
#  17,
#  989,
#  11,
#  5,
#  567,
#  1606,
#  26,
#  10,
#  13,
#  32,
#  890,
#  19,
#  47,
#  848,
#  14619,
#  11,
#  0,
#  1834,
#  1,
#  173,
#  4790,
#  208,
#  4,
#  153,
#  10,
#  917,
#  14619,
#  5474,
#  23,
#  0,
#  419,
#  12954,
#  917,
#  10,
#  6904,
#  4,
#  32,
#  139,
#  35,
#  1346,
#  0,
#  2878,
#  1,
#  15134,
#  917,
#  154,
#  99,
#  3471,
#  38,
#  652,
#  445,
#  6,
#  89,
#  2,
#  3133,
#  43,
#  917,
#  11,
#  46,
#  3596,
#  54,
#  11,
#  15447,
#  1555,
#  13,
#  2966,
#  4,
#  44,
#  258,
#  14619,
#  1165,
#  153,
#  35,
#  88,
#  3223,
#  1132,
#  52,
#  38,
#  751,
#  445,
#  6,
#  89,
#  1049,
#  522,
#  2,
#  1792,
#  4,
#  5812,
#  23,
#  1556,
#  1,
#  5129,
#  2,
#  1293,
#  14619,
#  14,
#  2654,
#  1,
#  11118,
#  33,
#  35,
#  88,
#  30063,
#  967,
#  30,
#  1334,
#  518,
#  99,
#  1132,
#  2,
#  308,
#  159,
#  512,
#  0,
#  805,
#  1,
#  43,
#  1258,
#  218,
#  1258,
#  1037,
#  33,
#  1391,
#  0,
#  908,
#  1,
#  741,
#  64,
#  967,
#  4,
#  442,
#  32,
#  73,
#  2913,
#  19,
#  75,
#  3,
#  73,
#  2966,
#  27,
#  0,
#  1258,
#  1,
#  275,
#  1555,
#  159,
#  4319,
#  2521,
#  498,
#  4,
#  727,
#  10707,
#  18876,
#  30,
#  762,
#  246,
#  986,
#  73,
#  31,
#  177,
#  97,
#  6,
#  740,
#  3272,
#  23,
#  912,
#  6,
#  0,
#  362,
#  1,
#  442,
#  14619,
#  14,
#  948,
#  39,
#  2025,
#  222,
#  150,
#  741,
#  476,
#  1818,
#  2,
#  29,
#  2985,
#  39,
#  1021,
#  4,
#  0,
#  854,
#  1,
#  3,
#  12,
#  20,
#  12,
#  4,
#  302,
#  14619,
#  14,
#  602,
#  1,
#  917,
#  10,
#  647,
#  26,
#  17,
#  347,
#  4,
#  5,
#  112,
#  1,
#  311,
#  79,
#  29,
#  3569,
#  2,
#  59,
#  25,
#  6444,
#  4190,
#  1,
#  47,
#  1,
#  29,
#  948,
#  13,
#  50,
#  2159,
#  1590,
#  67,
#  621,
#  2749,
#  26635,
#  14,
#  15645,
#  4,
#  29,
#  0,
#  10521,
#  2,
#  44,
#  199,
#  26635,
#  1460,
#  19,
#  51,
#  636,
#  1046,
#  345,
#  1774,
#  133,
#  0,
#  2581,
#  1,
#  93,
#  917,
#  11,
#  5,
#  244,
#  389,
#  445,
#  4,
#  152,
#  2,
#  0,
#  147,
#  2581,
#  1,
#  371,
#  39,
#  4588,
#  21016,
#  28,
#  9222,
#  4,
#  0,
#  940,
#  1975,
#  1,
#  371,
#  19,
#  0,
#  1132,
#  25,
#  44,
#  1729,
#  35,
#  5230,
#  15645,
#  2,
#  5,
#  143,
#  1,
#  4,
#  33,
#  1132,
#  73,
#  9740,
#  4,
#  5831,
#  1,
#  53254,
#  66,
#  61,
#  26,
#  17,
#  4,
#  43,
#  567,
#  762,
#  6,
#  175,
#  94,
#  13,
#  118,
#  917,
#  684,
#  1146,
#  78,
#  123,
#  507,
#  13082,
#  5575,
#  310,
#  6,
#  369,
#  6,
#  4112,
#  0,
#  1798,
#  6,
#  118,
#  5470,
#  917,
#  2,
#  153,
#  71,
#  38,
#  4,
#  608,
#  183,
#  19,
#  10,
#  608,
#  199,
#  94,
#  184,
#  11,
#  71,
#  6201,
#  9078,
#  11,
#  7201,
#  71,
#  1225,
#  0,
#  33905,
#  1,
#  0,
#  1798,
#  26635,
#  363,
#  88,
#  391,
#  30,
#  4790,
#  35,
#  1046,
#  66,
#  0,
#  2759,
#  43706,
#  2070,
#  29,
#  948,
#  39,
#  2025,
#  24,
#  55,
#  9997,
#  7096,
#  141,
#  4190,
#  1,
#  29,
#  501,
#  25,
#  3239,
#  63,
#  10284,
#  5236,
#  3246,
#  9631,
#  4,
#  3,
#  ...]

# %%
## Your code here
import pandas as pd
int_pd = pd.DataFrame({'word': int_words})
#print(int_pd)
thr =  2
prob_pd_dict = dict(int_pd['word'].value_counts().apply(lambda x: 1 - np.sqrt(thr/x)))
#print(prob_pd_dict)
#int_pd_prob = int_pd.replace({'word': prob_pd_dict})
#print(int_pd_prob.head(n=100))

# %%
import random
#choice_pd = np.random.rand(len(int_words))
train_words = [word for word in int_words if prob_pd_dict[word] > random.random()]

# %% [markdown]
# ## Making batches

# %%
print(type(train_words))
print(train_words[0:10])
# Out:
# <class 'list'>
# [5236, 3083, 11, 5, 194, 1, 3133, 45, 58, 155]

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    win = np.random.randint(1, window_size+1)
    return words[idx-win:idx:win]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None])
    labels = tf.placeholder(tf.int32, shape=[None, 1])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1.0, 1.0), name='embedding')# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=1.0/np.sqrt(n_embedding)), name='softmax_w')# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab]), name='softmax_b')# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w , biases=softmax_b, labels=labels, inputs=embed, num_sampled=n_sampled, num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 8.2173 0.2996 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 7.8206 0.3018 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 7.2690 0.2914 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 6.7244 0.2896 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 6.3458 0.2872 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.9860 0.2849 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.8092 0.2809 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.6112 0.2837 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.3447 0.2840 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.1764 0.2839 sec/batch
# Nearest to more: by, note, becomes, meaning, paganism, supporting, mainly, development,
# Nearest to s: we, another, took, saw, tried, way, extracts, without,
# Nearest to in: as, took, eight, for, but, ottoman, ana, receiver,
# Nearest to which: holy, the, often, wald, jews, things, nature, disposes,
# Nearest to with: only, list, legacy, saying, mean, function, gandhi, hicks,
# Nearest to will: signed, subroutine, count, built, standard, infractions, labor, trilogy,
# Nearest to there: could, can, take, evidence, affinities, brutally, the, therefore,
# Nearest to four: were, hurricane, j, neville, bull, frederick, among, russian,
# Nearest to award: boy, fifties, dtd, reasonableness, didn, kyd, browed, mortally,
# Nearest to governor: woogie, player, trapper, region, standard, among, hockey, modern,
# Nearest to marriage: usually, nutty, dissenter, motto, arden, felsic, eurasiatic, spl,
# Nearest to instance: scouting, empire, times, withdrew, aqdas, lazuli, automotive, jovial,
# Nearest to ocean: datuk, jousting, queen, hastings, clustered, columnists, henceforward, poured,
# Nearest to professional: black, hill, receding, netanya, unchecked, invalid, variances, young,
# Nearest to animals: arbitron, palestrina, miscarriages, smuts, superior, burnley, anapestic, subordo,
# Nearest to accepted: albertus, magnus, overrun, aguilar, oued, unitarians, combos, penderecki,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.1014 0.3033 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.1804 0.2999 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.0414 0.2955 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.0427 105.8327 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.9595 0.3109 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.9182 0.4133 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.9058 0.3559 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.8161 0.3643 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.8731 0.3367 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.7996 0.3085 sec/batch
# Nearest to more: paganism, by, product, jersey, consider, note, senses, moving,
# Nearest to s: plus, tried, citizens, saw, we, extracts, translated, another,
# Nearest to in: as, for, ana, eight, but, took, ottoman, palette,
# Nearest to which: the, holy, things, often, management, jews, wald, tombs,
# Nearest to with: only, list, tribute, saying, hicks, sacraments, video, gandhi,
# Nearest to will: subroutine, count, signed, faq, trilogy, collective, buildings, obligations,
# Nearest to there: affinities, jerusalem, can, brutally, could, bound, possessed, domestic,
# Nearest to four: hurricane, j, determination, deck, plus, protocols, iran, contrary,
# Nearest to award: boy, didn, effective, mortally, dtd, allows, finish, release,
# Nearest to governor: woogie, player, revenues, trapper, region, pilot, hockey, standard,
# Nearest to marriage: usually, motto, dissenter, nutty, ran, portugal, pat, display,
# Nearest to instance: withdrew, times, empire, automotive, scouting, naturalist, stated, nearby,
# Nearest to ocean: queen, prophets, datuk, sports, spite, location, clustered, scaled,
# Nearest to professional: hill, black, era, product, young, invalid, bring, competent,
# Nearest to animals: superior, full, joseph, commitment, arbitron, column, burnley, palestrina,
# Nearest to accepted: albertus, magnus, overrun, southeast, jack, roman, good, globe,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.8032 0.3338 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8177 0.3434 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.7249 0.3689 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.6876 0.3406 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7235 0.3375 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7139 0.3416 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7329 0.3324 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.6864 0.3086 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.6800 0.3027 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.6035 0.3524 sec/batch
# Nearest to more: paganism, consider, by, spurred, gif, moving, amtrak, product,
# Nearest to s: saw, plus, tried, extracts, citizens, tag, calligraphers, grandfather,
# Nearest to in: as, eight, for, ana, took, but, ottoman, representation,
# Nearest to which: the, holy, things, esters, bi, often, microsystems, dwellers,
# Nearest to with: only, list, tribute, saying, councillors, hicks, europeans, legacy,
# Nearest to will: subroutine, faq, creature, obligations, signed, schedule, romania, noteworthy,
# Nearest to there: fao, affinities, jerusalem, brutally, can, could, bi, possessed,
# Nearest to four: hurricane, j, protocols, catherine, determination, iran, plus, neville,
# Nearest to award: boy, didn, eponymous, fifties, effective, finish, mortally, dtd,
# Nearest to governor: woogie, player, trapper, revenues, cairo, hockey, pilot, dora,
# Nearest to marriage: motto, nutty, dissenter, usually, arden, portugal, ran, pat,
# Nearest to instance: scouting, humid, withdrew, automotive, empire, naturalist, struggle, times,
# Nearest to ocean: poured, queen, clustered, scaled, datuk, spite, statements, location,
# Nearest to professional: hill, quarters, black, competent, era, bring, receding, invalid,
# Nearest to animals: batman, superior, arbitron, burnley, commitment, palestrina, fractional, joseph,
# Nearest to accepted: albertus, magnus, overrun, southeast, globe, eponymous, justify, roman,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.6051 0.3560 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.6372 0.3231 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6473 0.3383 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6434 0.3090 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.6022 0.3196 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.5830 0.3285 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6281 0.2847 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.6281 0.3268 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.5072 0.3818 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.4769 0.3221 sec/batch
# Nearest to more: paganism, senses, product, becomes, concerned, spurred, by, consider,
# Nearest to s: extracts, plus, tried, saw, tag, grandfather, citizens, calligraphers,
# Nearest to in: for, eight, ana, as, took, representation, palette, but,
# Nearest to which: the, holy, things, microsystems, bi, esters, often, oriented,
# Nearest to with: only, tribute, list, sacraments, saying, responsive, councillors, hicks,
# Nearest to will: subroutine, faq, creature, schedule, obligations, noteworthy, anger, infractions,
# Nearest to there: brutally, fao, affinities, possessed, jerusalem, can, pottery, bi,
# Nearest to four: hurricane, j, catherine, protocols, neville, plus, est, determination,
# Nearest to award: boy, didn, mortally, fifties, finish, effective, eponymous, kyd,
# Nearest to governor: woogie, player, trapper, revenues, molar, wasting, cairo, portability,
# Nearest to marriage: motto, nutty, arden, dissenter, usually, ran, portugal, pat,
# Nearest to instance: scouting, humid, automotive, withdrew, naturalist, empire, lazuli, precipitating,
# Nearest to ocean: poured, clustered, exceedingly, datuk, spite, scaled, consoles, missing,
# Nearest to professional: quarters, hill, receding, black, competent, pious, product, dressed,
# Nearest to animals: fractional, arbitron, batman, superior, commitment, palestrina, burnley, obsession,
# Nearest to accepted: albertus, overrun, magnus, southeast, requesting, justify, roman, unitarians,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6348 0.3615 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.5938 0.3130 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5516 0.3150 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.5326 0.3083 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.5735 0.2925 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.5458 0.2976 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.5938 0.3051 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.5442 0.3152 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.5660 0.3222 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.5870 0.3119 sec/batch
# Nearest to more: paganism, spurred, senses, franchises, product, gamblers, concerned, gif,
# Nearest to s: extracts, calligraphers, ideological, tag, tried, plus, saw, recognising,
# Nearest to in: for, eight, as, palette, ana, polarized, representation, bea,
# Nearest to which: the, holy, things, microsystems, bi, esters, imitate, jews,
# Nearest to with: only, tribute, sacraments, saying, list, councillors, responsive, hicks,
# Nearest to will: subroutine, faq, obligations, anger, cameos, creature, pohl, coercion,
# Nearest to there: brutally, affinities, fao, can, pottery, bi, nicol, possessed,
# Nearest to four: catherine, hurricane, j, neville, conscientious, est, protocols, vivian,
# Nearest to award: boy, kyd, didn, fifties, mortally, finish, browed, eponymous,
# Nearest to governor: woogie, molar, wasting, cairo, trapper, player, revenues, wadsworth,
# Nearest to marriage: motto, dissenter, nutty, arden, usually, portugal, ran, roi,
# Nearest to instance: scouting, humid, lazuli, automotive, withdrew, naturalist, rtl, empire,
# Nearest to ocean: poured, exceedingly, spite, ddd, datuk, scaled, cousins, clustered,
# Nearest to professional: quarters, hill, abused, receding, black, pious, competent, bernie,
# Nearest to animals: palestrina, fractional, arbitron, batman, burnley, commitment, superior, obsession,
# Nearest to accepted: albertus, overrun, magnus, requesting, justify, unitarians, roman, southeast,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.5499 0.3129 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.5499 0.3106 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.5501 0.2960 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.5114 0.3425 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.5014 0.3103 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.5092 0.3027 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.5601 0.2958 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.5572 0.3054 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.4745 0.3015 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.5037 0.2908 sec/batch
# Nearest to more: paganism, spurred, senses, franchises, product, gamblers, note, gif,
# Nearest to s: extracts, calligraphers, tried, tag, ideological, saw, plus, grandfather,
# Nearest to in: for, palette, as, eight, polarized, ana, took, representation,
# Nearest to which: the, holy, things, microsystems, esters, bi, wald, compensates,
# Nearest to with: only, councillors, tribute, sacraments, saying, list, interception, mcgraw,
# Nearest to will: subroutine, faq, obligations, creature, cameos, judd, noteworthy, adjoint,
# Nearest to there: brutally, affinities, fao, pottery, can, anabaptist, bound, ok,
# Nearest to four: hurricane, j, catherine, est, neville, sq, conscientious, vivian,
# Nearest to award: boy, kyd, fifties, didn, mortally, eponymous, browed, finish,
# Nearest to governor: woogie, molar, wasting, cairo, trapper, wadsworth, player, revenues,
# Nearest to marriage: motto, dissenter, arden, nutty, usually, roi, ran, portugal,
# Nearest to instance: scouting, automotive, lazuli, humid, naturalist, morally, rtl, withdrew,
# Nearest to ocean: exceedingly, chomsky, poured, datuk, spite, cousins, clustered, ddd,
# Nearest to professional: hill, quarters, receding, pious, abused, unchecked, bernie, product,
# Nearest to animals: palestrina, fractional, arbitron, superior, burnley, commitment, batman, phd,
# Nearest to accepted: albertus, overrun, unitarians, southeast, magnus, justify, botany, eponymous,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.5166 0.3102 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.4460 0.3421 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.5075 0.3206 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.5051 0.2966 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.4760 0.2871 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.4864 0.3031 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.5276 0.3097 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.4857 0.3159 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.4910 0.3110 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.4278 0.3125 sec/batch
# Nearest to more: spurred, paganism, gamblers, product, senses, franchises, evacuate, carolyn,
# Nearest to s: extracts, calligraphers, shamanic, ideological, inevitably, tag, borrow, tried,
# Nearest to in: ana, palette, for, eight, as, polarized, took, bea,
# Nearest to which: the, holy, things, microsystems, esters, compensates, popes, bi,
# Nearest to with: only, sacraments, councillors, saying, tribute, interception, list, unethical,
# Nearest to will: subroutine, obligations, cameos, faq, creature, judd, anger, rains,
# Nearest to there: brutally, affinities, pottery, fao, ok, anabaptist, db, domestic,
# Nearest to four: hurricane, est, catherine, conscientious, j, sq, lifeforms, vivian,
# Nearest to award: boy, fifties, kyd, didn, mortally, eponymous, ato, dtd,
# Nearest to governor: woogie, molar, wadsworth, wasting, trapper, player, cairo, revenues,
# Nearest to marriage: dissenter, motto, arden, nutty, spl, roi, usually, ran,
# Nearest to instance: scouting, lazuli, automotive, humid, nederlandse, withdrew, definitions, naturalist,
# Nearest to ocean: exceedingly, chomsky, cousins, datuk, ddd, spite, nationalistic, poured,
# Nearest to professional: receding, hill, abused, quarters, morton, pious, unchecked, preachers,
# Nearest to animals: fractional, palestrina, arbitron, superior, burnley, commitment, phd, batman,
# Nearest to accepted: albertus, overrun, unitarians, usher, botany, magnus, eponymous, requesting,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.4986 0.3133 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.4225 0.3012 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.5189 0.3037 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.4773 0.2975 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.5066 0.2837 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.4596 0.2896 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.4979 0.2795 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.4613 0.2785 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.4677 0.2703 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.4542 0.2807 sec/batch
# Nearest to more: spurred, paganism, carolyn, gamblers, franchises, product, senses, amtrak,
# Nearest to s: extracts, calligraphers, abiotic, shamanic, saw, borrow, plus, grandfather,
# Nearest to in: palette, eight, for, took, polarized, ana, as, receiver,
# Nearest to which: the, holy, things, compensates, microsystems, imitate, lola, housewife,
# Nearest to with: only, saying, councillors, sacraments, tribute, interception, unethical, override,
# Nearest to will: subroutine, cameos, creature, judd, obligations, faq, collective, adjoint,
# Nearest to there: brutally, affinities, pottery, anabaptist, ok, fao, db, domestic,
# Nearest to four: est, hurricane, catherine, j, sq, conscientious, lifeforms, vivian,
# Nearest to award: boy, fifties, kyd, didn, mortally, ato, parthian, eponymous,
# Nearest to governor: woogie, molar, wadsworth, wasting, cairo, revenues, trapper, undesired,
# Nearest to marriage: arden, dissenter, motto, nutty, spl, roi, portugal, bani,
# Nearest to instance: lazuli, scouting, automotive, humid, nederlandse, signifies, definitions, escaping,
# Nearest to ocean: chomsky, exceedingly, cousins, datuk, nationalistic, ddd, poured, corvette,
# Nearest to professional: receding, abused, hill, quarters, pious, product, rove, preachers,
# Nearest to animals: fractional, palestrina, arbitron, burnley, superior, commitment, batman, smuts,
# Nearest to accepted: albertus, usher, overrun, unitarians, magnus, requesting, eponymous, botany,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.4859 0.2891 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.3870 0.2877 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.4059 0.3014 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.4671 0.2977 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.4320 0.2963 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.5081 0.3027 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.4703 0.3002 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.4406 0.3142 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.4519 0.3097 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.4547 0.3035 sec/batch
# Nearest to more: spurred, paganism, carolyn, gamblers, franchises, regression, hendrix, product,
# Nearest to s: extracts, calligraphers, abiotic, shamanic, ideological, borrow, tried, unemployed,
# Nearest to in: palette, for, eight, as, polarized, ana, stimulated, amounts,
# Nearest to which: the, holy, things, microsystems, frisians, housewife, compensates, lola,
# Nearest to with: only, councillors, tribute, sacraments, interception, saying, unethical, override,
# Nearest to will: subroutine, cameos, judd, faq, gda, obligations, creature, adjoint,
# Nearest to there: brutally, affinities, anabaptist, pottery, ok, bound, predictability, domestic,
# Nearest to four: catherine, vivian, est, conscientious, lifeforms, hurricane, j, sq,
# Nearest to award: boy, fifties, kyd, didn, mortally, ato, eponymous, parthian,
# Nearest to governor: woogie, wadsworth, molar, cairo, wasting, revenues, organising, player,
# Nearest to marriage: arden, dissenter, nutty, roi, motto, spl, leaching, usually,
# Nearest to instance: scouting, lazuli, automotive, nederlandse, humid, arise, escaping, morally,
# Nearest to ocean: chomsky, nationalistic, exceedingly, datuk, advise, ddd, cousins, spite,
# Nearest to professional: receding, abused, guise, unchecked, hill, quarters, pious, product,
# Nearest to animals: fractional, palestrina, arbitron, burnley, commitment, superior, batman, phd,
# Nearest to accepted: albertus, unitarians, usher, magnus, overrun, requesting, neo, eponymous,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 4.3475 0.3122 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 4.4578 0.2987 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 4.4382 0.2913 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 4.4578 0.2846 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.4853 0.2811 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.4439 0.2821 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.4836 0.2886 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.4517 0.2859 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.4285 0.2989 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.4116 0.3095 sec/batch
# Nearest to more: spurred, paganism, carolyn, gamblers, regression, franchises, senses, hendrix,
# Nearest to s: extracts, calligraphers, shamanic, abiotic, ideological, tried, unemployed, discard,
# Nearest to in: palette, eight, the, for, as, polarized, ana, took,
# Nearest to which: the, holy, things, frisians, microsystems, compensates, housewife, sublime,
# Nearest to with: only, interception, councillors, sacraments, unethical, saying, tribute, override,
# Nearest to will: subroutine, cameos, judd, anger, qf, creature, obligations, faq,
# Nearest to there: brutally, anabaptist, affinities, pottery, bound, fao, ok, domestic,
# Nearest to four: est, catherine, lifeforms, conscientious, vivian, sq, hurricane, cumin,
# Nearest to award: boy, kyd, fifties, mortally, didn, oeuvres, nayla, parthian,
# Nearest to governor: woogie, wadsworth, molar, wasting, cairo, anomalous, revenues, skull,
# Nearest to marriage: dissenter, arden, nutty, roi, motto, spl, ran, portugal,
# Nearest to instance: lazuli, scouting, nederlandse, humid, automotive, lenten, morally, rtl,
# Nearest to ocean: nationalistic, exceedingly, chomsky, datuk, advise, ddd, corvette, spite,
# Nearest to professional: receding, abused, guise, unchecked, pious, hill, cod, guessed,
# Nearest to animals: palestrina, fractional, arbitron, burnley, superior, batman, commitment, smuts,
# Nearest to accepted: albertus, magnus, overrun, unitarians, requesting, usher, botany, intermediates,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.4526 0.3241 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.4685 0.3166 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.4226 0.3064 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.4060 0.3008 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.4501 0.2932 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.4369 0.2947 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.4351 0.3092 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.4396 0.3266 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.4672 0.3171 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.4344 0.2993 sec/batch
# Nearest to more: spurred, paganism, gamblers, carolyn, evacuate, regression, infrastructural, lumps,
# Nearest to s: extracts, shamanic, calligraphers, abiotic, ideological, unemployed, discard, lysander,
# Nearest to in: the, for, as, palette, eight, reforming, thinly, polarized,
# Nearest to which: the, holy, frisians, housewife, microsystems, compensates, sublime, things,
# Nearest to with: only, tribute, unethical, interception, saying, override, councillors, a,
# Nearest to will: subroutine, cameos, judd, qf, obligations, creature, anger, collective,
# Nearest to there: anabaptist, affinities, brutally, bound, pottery, ok, fao, spruce,
# Nearest to four: catherine, est, lifeforms, conscientious, vivian, sq, hurricane, cumin,
# Nearest to award: boy, kyd, fifties, mortally, parthian, oeuvres, didn, nayla,
# Nearest to governor: woogie, wadsworth, molar, wasting, cairo, mens, revenues, daimyo,
# Nearest to marriage: dissenter, arden, roi, nutty, spl, portugal, pat, motto,
# Nearest to instance: lazuli, scouting, nederlandse, automotive, humid, morally, rtl, lenten,
# Nearest to ocean: nationalistic, exceedingly, datuk, cousins, chomsky, ecoregions, ddd, lsd,
# Nearest to professional: receding, abused, unchecked, lighten, variances, cod, guise, hill,
# Nearest to animals: palestrina, fractional, arbitron, burnley, superior, batman, miscarriages, commitment,
# Nearest to accepted: albertus, unitarians, overrun, requesting, indicated, botany, dictate, intermediates,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 4.4199 0.3038 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.3753 0.2853 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 4.4044 0.2854 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 4.4645 0.2887 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.3326 0.2884 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.4226 0.2870 sec/batch
# Epoch 1/10 Iteration: 11700 Avg. Training loss: 4.4158 0.2840 sec/batch
# Epoch 1/10 Iteration: 11800 Avg. Training loss: 4.3766 0.2967 sec/batch
# Epoch 1/10 Iteration: 11900 Avg. Training loss: 4.4623 0.3021 sec/batch
# Epoch 1/10 Iteration: 12000 Avg. Training loss: 4.2043 0.3061 sec/batch
# Nearest to more: spurred, carolyn, gamblers, paganism, regression, evacuate, lumps, infrastructural,
# Nearest to s: extracts, calligraphers, shamanic, abiotic, discard, tried, fulcrum, areal,
# Nearest to in: the, for, eight, reforming, ana, as, thinly, of,
# Nearest to which: the, frisians, holy, sublime, microsystems, housewife, things, compensates,
# Nearest to with: only, unethical, tribute, councillors, a, saying, interception, override,
# Nearest to will: subroutine, cameos, judd, obligations, qf, creature, anger, ankan,
# Nearest to there: anabaptist, affinities, pottery, ok, bound, brutally, spruce, annabella,
# Nearest to four: est, sq, catherine, vivian, eight, one, lifeforms, conscientious,
# Nearest to award: kyd, boy, fifties, oeuvres, parthian, mortally, ato, didn,
# Nearest to governor: woogie, wadsworth, molar, cairo, mens, wasting, organising, trapper,
# Nearest to marriage: arden, dissenter, roi, nutty, spl, bani, motto, leaching,
# Nearest to instance: lazuli, scouting, automotive, nederlandse, humid, definitions, arise, escaping,
# Nearest to ocean: exceedingly, nationalistic, ecoregions, datuk, kan, ddd, chomsky, cousins,
# Nearest to professional: receding, abused, unchecked, scrapped, netanya, variances, wyndham, quarters,
# Nearest to animals: palestrina, fractional, arbitron, burnley, commitment, smuts, superior, batman,
# Nearest to accepted: albertus, overrun, requesting, botany, unitarians, usher, eponymous, indicated,
# Epoch 1/10 Iteration: 12100 Avg. Training loss: 3.9952 0.3060 sec/batch
# Epoch 1/10 Iteration: 12200 Avg. Training loss: 4.3726 0.3003 sec/batch
# Epoch 1/10 Iteration: 12300 Avg. Training loss: 4.1821 0.3008 sec/batch
# Epoch 1/10 Iteration: 12400 Avg. Training loss: 4.2954 0.3094 sec/batch
# Epoch 1/10 Iteration: 12500 Avg. Training loss: 4.3592 0.3056 sec/batch
# Epoch 1/10 Iteration: 12600 Avg. Training loss: 4.3823 0.3042 sec/batch
# Epoch 1/10 Iteration: 12700 Avg. Training loss: 4.3583 0.3027 sec/batch
# Epoch 1/10 Iteration: 12800 Avg. Training loss: 4.4239 0.3038 sec/batch
# Epoch 1/10 Iteration: 12900 Avg. Training loss: 4.4304 0.3058 sec/batch
# Epoch 1/10 Iteration: 13000 Avg. Training loss: 4.4626 0.3348 sec/batch
# Nearest to more: gamblers, spurred, carolyn, evacuate, paganism, regression, lumps, hendrix,
# Nearest to s: extracts, shamanic, abiotic, calligraphers, ideological, areal, fulcrum, tried,
# Nearest to in: the, for, polarized, eight, palette, as, ana, took,
# Nearest to which: the, holy, sublime, frisians, microsystems, nihonshoki, housewife, lola,
# Nearest to with: only, unethical, tribute, saying, councillors, mcgraw, interception, a,
# Nearest to will: subroutine, cameos, obligations, judd, anger, qf, creature, ankan,
# Nearest to there: anabaptist, ok, annabella, brutally, pottery, affinities, clockwork, spruce,
# Nearest to four: catherine, conscientious, vivian, est, sq, lifeforms, protocols, eight,
# Nearest to award: kyd, boy, fifties, oeuvres, reasonableness, nayla, parthian, ato,
# Nearest to governor: woogie, wadsworth, molar, storefront, daimyo, cairo, wasting, mens,
# Nearest to marriage: dissenter, arden, roi, nutty, spl, ran, leaching, motto,
# Nearest to instance: lazuli, scouting, automotive, nederlandse, humid, morally, definitions, signifies,
# Nearest to ocean: datuk, exceedingly, ecoregions, kan, cousins, nationalistic, chomsky, jousting,
# Nearest to professional: receding, scrapped, netanya, abused, rove, morton, unchecked, variances,
# Nearest to animals: palestrina, fractional, arbitron, burnley, smuts, commitment, batman, miscarriages,
# Nearest to accepted: albertus, botany, overrun, requesting, unitarians, eponymous, usher, investigated,
# Epoch 1/10 Iteration: 13100 Avg. Training loss: 4.4579 0.3185 sec/batch
# Epoch 1/10 Iteration: 13200 Avg. Training loss: 4.4387 0.3157 sec/batch
# Epoch 1/10 Iteration: 13300 Avg. Training loss: 4.4594 0.3092 sec/batch
# Epoch 1/10 Iteration: 13400 Avg. Training loss: 4.4496 0.3259 sec/batch
# Epoch 1/10 Iteration: 13500 Avg. Training loss: 4.3093 0.3236 sec/batch
# Epoch 1/10 Iteration: 13600 Avg. Training loss: 4.3708 0.3034 sec/batch
# Epoch 1/10 Iteration: 13700 Avg. Training loss: 4.4367 0.3010 sec/batch
# Epoch 1/10 Iteration: 13800 Avg. Training loss: 4.4145 0.2983 sec/batch
# Epoch 1/10 Iteration: 13900 Avg. Training loss: 4.3913 0.3283 sec/batch
# Epoch 1/10 Iteration: 14000 Avg. Training loss: 4.4526 0.3264 sec/batch
# Nearest to more: carolyn, evacuate, gamblers, spurred, lumps, hendrix, paganism, sprouted,
# Nearest to s: extracts, shamanic, abiotic, calligraphers, areal, ideological, fulcrum, paging,
# Nearest to in: the, for, receiver, stimulated, as, polarized, eight, palette,
# Nearest to which: the, holy, frisians, sublime, nihonshoki, microsystems, sufis, clearinghouse,
# Nearest to with: only, tribute, unethical, interception, a, participate, executors, guzman,
# Nearest to will: subroutine, cameos, judd, obligations, creature, qf, if, adjoint,
# Nearest to there: anabaptist, annabella, affinities, spruce, brutally, spoil, pottery, ok,
# Nearest to four: catherine, est, conscientious, vivian, lifeforms, sq, hurricane, sejm,
# Nearest to award: boy, kyd, fifties, oeuvres, reasonableness, nayla, ato, mortally,
# Nearest to governor: woogie, wadsworth, molar, wasting, daimyo, storefront, trapper, cairo,
# Nearest to marriage: arden, dissenter, nutty, roi, spl, ran, leaching, eurasiatic,
# Nearest to instance: lazuli, scouting, morally, nederlandse, humid, definitions, signifies, automotive,
# Nearest to ocean: datuk, exceedingly, ecoregions, kan, cousins, nationalistic, chomsky, jousting,
# Nearest to professional: receding, rove, scrapped, unchecked, netanya, abused, variances, guessed,
# Nearest to animals: palestrina, arbitron, fractional, burnley, smuts, commitment, recombination, miscarriages,
# Nearest to accepted: albertus, botany, overrun, requesting, unitarians, usher, investigated, intermediates,
# Epoch 1/10 Iteration: 14100 Avg. Training loss: 4.4273 0.2956 sec/batch
# Epoch 1/10 Iteration: 14200 Avg. Training loss: 4.4774 0.2885 sec/batch
# Epoch 1/10 Iteration: 14300 Avg. Training loss: 4.3835 0.2770 sec/batch
# Epoch 1/10 Iteration: 14400 Avg. Training loss: 4.4517 0.2872 sec/batch
# Epoch 1/10 Iteration: 14500 Avg. Training loss: 4.3538 0.2910 sec/batch
# Epoch 1/10 Iteration: 14600 Avg. Training loss: 4.2262 0.2918 sec/batch
# Epoch 1/10 Iteration: 14700 Avg. Training loss: 4.3172 0.2904 sec/batch
# Epoch 1/10 Iteration: 14800 Avg. Training loss: 4.3824 0.2900 sec/batch
# Epoch 1/10 Iteration: 14900 Avg. Training loss: 4.4012 0.2853 sec/batch
# Epoch 1/10 Iteration: 15000 Avg. Training loss: 4.2109 0.2784 sec/batch
# Nearest to more: carolyn, lumps, spurred, evacuate, gamblers, franchises, regression, paganism,
# Nearest to s: extracts, shamanic, abiotic, calligraphers, ideological, fulcrum, areal, paging,
# Nearest to in: the, for, polarized, palette, reforming, as, unsubstantiated, receiver,
# Nearest to which: the, holy, sublime, frisians, nihonshoki, microsystems, precedence, things,
# Nearest to with: only, unethical, tribute, interception, executors, guzman, sacraments, participate,
# Nearest to will: subroutine, cameos, judd, creature, qf, if, obligations, adjoint,
# Nearest to there: anabaptist, annabella, affinities, ok, spoil, healthier, bound, brutally,
# Nearest to four: catherine, est, eight, one, vivian, sq, conscientious, lillie,
# Nearest to award: boy, kyd, fifties, oeuvres, nayla, reasonableness, ato, mortally,
# Nearest to governor: woogie, wadsworth, molar, wasting, cairo, mens, daimyo, engenders,
# Nearest to marriage: arden, dissenter, roi, nutty, ran, spl, leaching, eurasiatic,
# Nearest to instance: lazuli, scouting, nederlandse, morally, automotive, definitions, humid, lenten,
# Nearest to ocean: kan, datuk, nationalistic, exceedingly, jousting, ecoregions, basin, cousins,
# Nearest to professional: receding, scrapped, rove, unchecked, netanya, guise, cod, guessed,
# Nearest to animals: palestrina, arbitron, fractional, burnley, smuts, commitment, wf, miscarriages,
# Nearest to accepted: albertus, botany, overrun, requesting, unitarians, investigated, usher, aguilar,
# Epoch 1/10 Iteration: 15100 Avg. Training loss: 4.3798 0.2990 sec/batch
# Epoch 1/10 Iteration: 15200 Avg. Training loss: 4.4221 0.2828 sec/batch
# Epoch 1/10 Iteration: 15300 Avg. Training loss: 4.4117 0.2874 sec/batch
# Epoch 1/10 Iteration: 15400 Avg. Training loss: 4.3894 0.2911 sec/batch
# Epoch 1/10 Iteration: 15500 Avg. Training loss: 4.2946 0.2966 sec/batch
# Epoch 1/10 Iteration: 15600 Avg. Training loss: 4.3323 0.2904 sec/batch
# Epoch 1/10 Iteration: 15700 Avg. Training loss: 4.3816 0.2827 sec/batch
# Epoch 1/10 Iteration: 15800 Avg. Training loss: 4.4258 0.2794 sec/batch
# Epoch 1/10 Iteration: 15900 Avg. Training loss: 4.4638 0.2886 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.4403 0.0845 sec/batch
# Nearest to more: lumps, evacuate, gamblers, spurred, franchises, carolyn, dwarves, regression,
# Nearest to s: abiotic, shamanic, extracts, paging, calligraphers, fulcrum, discard, chaco,
# Nearest to in: the, for, palette, a, as, freedman, unsubstantiated, hopefully,
# Nearest to which: the, holy, frisians, sublime, nihonshoki, microsystems, precedence, sufis,
# Nearest to with: only, unethical, tribute, interception, sacraments, guzman, executors, participate,
# Nearest to will: subroutine, cameos, judd, adjoint, qf, vern, anger, if,
# Nearest to there: annabella, ok, anabaptist, affinities, bound, spoil, brutally, healthier,
# Nearest to four: vivian, catherine, conscientious, eight, est, sq, sejm, lillie,
# Nearest to award: boy, kyd, fifties, oeuvres, nayla, reasonableness, parthian, paparizou,
# Nearest to governor: woogie, wadsworth, molar, wasting, daimyo, waffen, storefront, mens,
# Nearest to marriage: arden, dissenter, nutty, spl, roi, leaching, ran, plasmas,
# Nearest to instance: lazuli, scouting, automotive, morally, nederlandse, definitions, humid, arise,
# Nearest to ocean: exceedingly, nationalistic, datuk, ecoregions, jousting, kan, basin, chomsky,
# Nearest to professional: receding, scrapped, unchecked, rove, netanya, variances, guessed, guise,
# Nearest to animals: palestrina, arbitron, fractional, burnley, smuts, commitment, recombination, miscarriages,
# Nearest to accepted: albertus, botany, requesting, unitarians, overrun, usher, aguilar, investigated,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.4335 0.2978 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.3657 0.2997 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.3735 0.2940 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.4184 0.2852 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.3323 0.2864 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.3541 0.2864 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.3305 0.2929 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.3660 0.3041 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.2408 0.3122 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.2517 0.3066 sec/batch
# Nearest to more: lumps, paganism, carolyn, gamblers, evacuate, franchises, regression, spurred,
# Nearest to s: abiotic, extracts, shamanic, paging, calligraphers, areal, fulcrum, ideological,
# Nearest to in: the, for, palette, as, and, of, a, but,
# Nearest to which: the, holy, frisians, sublime, nihonshoki, microsystems, precedence, sufis,
# Nearest to with: only, unethical, participate, tribute, override, guzman, interception, sacraments,
# Nearest to will: subroutine, cameos, qf, judd, adjoint, vern, epicureanism, rains,
# Nearest to there: annabella, ok, anabaptist, brutally, bound, spruce, healthier, could,
# Nearest to four: catherine, eight, one, vivian, sq, conscientious, six, jails,
# Nearest to award: boy, kyd, fifties, oeuvres, reasonableness, nayla, paparizou, ato,
# Nearest to governor: woogie, wadsworth, molar, waffen, engenders, daimyo, mens, storefront,
# Nearest to marriage: arden, dissenter, nutty, leaching, roi, ran, spl, bactrian,
# Nearest to instance: scouting, lazuli, morally, humid, automotive, definitions, nederlandse, lenten,
# Nearest to ocean: nationalistic, datuk, kan, exceedingly, basin, ecoregions, jousting, bourne,
# Nearest to professional: receding, scrapped, rove, unchecked, abused, netanya, quarters, variances,
# Nearest to animals: fractional, palestrina, arbitron, burnley, miscarriages, smuts, commitment, wf,
# Nearest to accepted: albertus, botany, requesting, unitarians, overrun, eligius, justify, investigated,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.2910 0.3135 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.3637 0.3063 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.3550 0.3064 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.3179 0.2993 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.3651 0.3018 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.3518 0.2947 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.3558 0.2947 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.3506 0.2941 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.3796 0.2899 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.3598 0.3164 sec/batch
# Nearest to more: gamblers, lumps, paganism, carolyn, regression, evacuate, pianos, ninurta,
# Nearest to s: extracts, abiotic, fulcrum, calligraphers, areal, lysander, paging, shamanic,
# Nearest to in: the, for, as, palette, gryphon, at, and, a,
# Nearest to which: the, frisians, holy, nihonshoki, microsystems, precedence, mehmet, sublime,
# Nearest to with: only, unethical, tribute, a, sacraments, executors, interception, override,
# Nearest to will: subroutine, cameos, judd, vern, adjoint, epicureanism, ankan, silky,
# Nearest to there: bound, ok, anabaptist, brutally, annabella, the, clockwork, healthier,
# Nearest to four: catherine, eight, vivian, jails, sq, sejm, longman, six,
# Nearest to award: boy, kyd, fifties, oeuvres, reasonableness, nayla, paparizou, parthian,
# Nearest to governor: woogie, wadsworth, daimyo, molar, engenders, mens, storefront, cairo,
# Nearest to marriage: arden, dissenter, nutty, leaching, spl, roi, eurasiatic, ran,
# Nearest to instance: scouting, lazuli, definitions, humid, automotive, nederlandse, morally, lenten,
# Nearest to ocean: nationalistic, exceedingly, ecoregions, datuk, basin, jousting, kan, coast,
# Nearest to professional: receding, rove, scrapped, unchecked, hoxha, quarters, variances, guessed,
# Nearest to animals: palestrina, arbitron, fractional, burnley, miscarriages, smuts, commitment, agassi,
# Nearest to accepted: albertus, requesting, botany, unitarians, eligius, overrun, investigated, usher,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.3885 0.3052 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.4145 0.2896 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.2181 0.2941 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.3932 0.2894 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.3745 0.2856 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.3750 0.2783 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.4068 0.2825 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.3908 0.2840 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 4.3619 0.2889 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.3214 0.2773 sec/batch
# Nearest to more: lumps, gamblers, paganism, evacuate, regression, carolyn, infrastructural, pianos,
# Nearest to s: extracts, abiotic, calligraphers, rios, fulcrum, areal, lysander, paging,
# Nearest to in: the, for, palette, and, a, as, at, eight,
# Nearest to which: the, holy, frisians, nihonshoki, lola, mehmet, microsystems, sublime,
# Nearest to with: only, unethical, tribute, a, interception, the, sacraments, guzman,
# Nearest to will: subroutine, cameos, judd, springboard, adjoint, ankan, vern, epicureanism,
# Nearest to there: brutally, annabella, bound, anabaptist, ok, could, clockwork, dagobert,
# Nearest to four: catherine, eight, one, six, three, sq, sejm, vivian,
# Nearest to award: boy, fifties, kyd, oeuvres, parthian, nayla, reasonableness, paparizou,
# Nearest to governor: woogie, wadsworth, daimyo, mens, molar, engenders, storefront, cairo,
# Nearest to marriage: arden, dissenter, nutty, leaching, roi, portugal, spl, ran,
# Nearest to instance: lazuli, scouting, morally, automotive, nederlandse, humid, definitions, kohl,
# Nearest to ocean: ecoregions, datuk, nationalistic, basin, kan, exceedingly, jousting, donne,
# Nearest to professional: receding, rove, unchecked, scrapped, variances, ups, guise, netanya,
# Nearest to animals: arbitron, palestrina, fractional, burnley, miscarriages, smuts, commitment, recombination,
# Nearest to accepted: albertus, requesting, botany, unitarians, usher, roman, eligius, aguilar,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.3541 0.2846 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.3875 0.2751 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.3816 0.2739 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.3863 0.2862 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.3684 0.2823 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.3373 0.2841 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.3724 0.2843 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.3686 0.2821 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.2287 0.2897 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.3219 0.2851 sec/batch
# Nearest to more: gamblers, lumps, paganism, regression, evacuate, pianos, carolyn, infrastructural,
# Nearest to s: calligraphers, paging, abiotic, extracts, rios, fulcrum, areal, californian,
# Nearest to in: the, for, and, palette, of, as, tiring, a,
# Nearest to which: the, sublime, frisians, holy, precedence, nihonshoki, lola, mehmet,
# Nearest to with: unethical, only, tribute, interception, a, sacraments, override, guzman,
# Nearest to will: subroutine, cameos, judd, vern, epicureanism, springboard, ankan, adjoint,
# Nearest to there: brutally, annabella, ok, bound, anabaptist, could, pottery, dagobert,
# Nearest to four: eight, one, catherine, six, sq, three, est, zero,
# Nearest to award: fifties, boy, kyd, oeuvres, nayla, reasonableness, parthian, paparizou,
# Nearest to governor: woogie, wadsworth, daimyo, engenders, molar, storefront, mens, wasting,
# Nearest to marriage: arden, dissenter, nutty, leaching, spl, eurasiatic, roi, ran,
# Nearest to instance: lazuli, scouting, automotive, morally, nederlandse, definitions, humid, cotangent,
# Nearest to ocean: basin, datuk, ecoregions, kan, coast, nationalistic, donne, jousting,
# Nearest to professional: receding, rove, ups, unchecked, variances, guise, scrapped, lighten,
# Nearest to animals: arbitron, palestrina, fractional, burnley, miscarriages, smuts, recombination, commitment,
# Nearest to accepted: albertus, requesting, unitarians, roman, botany, overrun, aguilar, krazy,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.4127 0.2898 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.3203 0.2893 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.3631 0.2818 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.3418 0.3443 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.3661 0.2777 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.3515 0.2766 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 4.3267 0.2772 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.3511 0.2905 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 4.4060 0.2822 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 4.3604 0.2835 sec/batch
# Nearest to more: lumps, regression, paganism, pianos, evacuate, gamblers, infrastructural, ninurta,
# Nearest to s: unemployed, extracts, calligraphers, paging, abiotic, fulcrum, areal, gothicus,
# Nearest to in: the, for, a, and, as, grammatik, at, palette,
# Nearest to which: the, frisians, sublime, sufis, disposes, holy, precedence, inclusions,
# Nearest to with: only, unethical, a, tribute, executors, guzman, the, interception,
# Nearest to will: subroutine, cameos, judd, ankan, vern, epicureanism, springboard, adjoint,
# Nearest to there: ok, brutally, anabaptist, bound, annabella, could, pottery, affinities,
# Nearest to four: eight, one, six, sq, three, catherine, zero, jails,
# Nearest to award: fifties, boy, kyd, nayla, reasonableness, oeuvres, paparizou, parthian,
# Nearest to governor: woogie, wadsworth, daimyo, engenders, cairo, molar, storefront, mens,
# Nearest to marriage: arden, dissenter, nutty, spl, leaching, blackstone, abelson, ran,
# Nearest to instance: lazuli, automotive, scouting, definitions, morally, cotangent, nederlandse, encomium,
# Nearest to ocean: basin, datuk, ecoregions, donne, jousting, coast, nationalistic, chomsky,
# Nearest to professional: receding, ups, rove, unchecked, lighten, netanya, variances, hoxha,
# Nearest to animals: arbitron, palestrina, fractional, burnley, miscarriages, recombination, smuts, commitment,
# Nearest to accepted: albertus, unitarians, overrun, requesting, roman, indicated, aguilar, krazy,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 4.3738 0.2888 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 4.3980 0.2740 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 4.3702 0.2830 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 4.3481 0.2824 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 4.3343 0.2882 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 4.3576 0.2874 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.4139 0.2790 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.3412 0.2872 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.3296 0.3005 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 4.3668 0.3045 sec/batch
# Nearest to more: regression, lumps, pianos, paganism, evacuate, gamblers, infrastructural, ninurta,
# Nearest to s: fulcrum, extracts, calligraphers, paging, abiotic, rios, gothicus, californian,
# Nearest to in: the, for, a, and, palette, grammatik, as, but,
# Nearest to which: the, disposes, sublime, sufis, holy, frisians, unlock, precedence,
# Nearest to with: only, unethical, a, interception, tribute, executors, the, zulus,
# Nearest to will: subroutine, cameos, ankan, judd, vern, adjoint, springboard, epicureanism,
# Nearest to there: anabaptist, brutally, ok, annabella, could, bound, pottery, realists,
# Nearest to four: eight, one, six, sq, three, zero, jails, est,
# Nearest to award: fifties, boy, kyd, reasonableness, nayla, oeuvres, parthian, paparizou,
# Nearest to governor: woogie, wadsworth, engenders, daimyo, cairo, storefront, mens, gaston,
# Nearest to marriage: arden, dissenter, spl, nutty, leaching, abelson, eurasiatic, blackstone,
# Nearest to instance: lazuli, automotive, morally, definitions, scouting, kohl, nederlandse, encomium,
# Nearest to ocean: basin, nationalistic, ecoregions, datuk, donne, coast, jousting, kan,
# Nearest to professional: receding, rove, ups, unchecked, variances, lighten, cod, netanya,
# Nearest to animals: arbitron, palestrina, fractional, burnley, miscarriages, smuts, humans, wf,
# Nearest to accepted: albertus, unitarians, aguilar, krazy, overrun, requesting, investigated, indicated,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 4.2690 0.3051 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 4.3680 0.3134 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 4.3585 0.2855 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 4.3615 0.2852 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 4.3582 0.2863 sec/batch
# Epoch 2/10 Iteration: 22600 Avg. Training loss: 4.3527 0.2860 sec/batch
# Epoch 2/10 Iteration: 22700 Avg. Training loss: 4.3898 0.2882 sec/batch
# Epoch 2/10 Iteration: 22800 Avg. Training loss: 4.3447 0.2883 sec/batch
# Epoch 2/10 Iteration: 22900 Avg. Training loss: 4.2996 0.2966 sec/batch
# Epoch 2/10 Iteration: 23000 Avg. Training loss: 4.3211 0.3023 sec/batch
# ...
# Nearest to s: one, u, the, nine, eight, roxen, machaut, this,
# Nearest to in: the, at, a, and, on, during, one, by,
# Nearest to which: the, called, and, a, usually, such, several, in,
# Nearest to with: and, a, disorganised, in, the, uu, quartile, but,
# Nearest to will: can, should, must, is, cannot, would, may, does,
# Nearest to there: are, it, they, many, some, is, has, only,
# Nearest to four: three, five, six, one, seven, two, eight, zero,
# Nearest to award: awards, best, grammy, prize, winning, medal, nomination, academy,
# Nearest to governor: daimyo, wadsworth, legislative, lieutenant, minister, delegate, bayh, incumbent,
# Nearest to marriage: murder, child, anne, married, parent, son, overwork, raincoat,
# Nearest to instance: example, reasons, purposes, see, purpose, disambiguation, decades, igf,
# Nearest to ocean: pacific, microwave, oceans, indian, atlantic, intelsat, islands, radiotelephone,
# Nearest to professional: indoor, transitioned, recommendations, ups, quarters, native, basketball, team,
# Nearest to animals: humans, human, organisms, mammals, species, shingles, recombination, physiology,
# Nearest to accepted: regarded, respected, universally, albertus, recognised, understood, known, identifies,
# Epoch 10/10 Iteration: 152100 Avg. Training loss: 4.1914 0.3919 sec/batch
# Epoch 10/10 Iteration: 152200 Avg. Training loss: 4.2186 0.3674 sec/batch
# Epoch 10/10 Iteration: 152300 Avg. Training loss: 4.1267 0.4053 sec/batch
# Epoch 10/10 Iteration: 152400 Avg. Training loss: 4.2594 0.3862 sec/batch
# Epoch 10/10 Iteration: 152500 Avg. Training loss: 4.2431 0.3855 sec/batch
# Epoch 10/10 Iteration: 152600 Avg. Training loss: 4.2234 0.3857 sec/batch
# Epoch 10/10 Iteration: 152700 Avg. Training loss: 4.2255 0.3901 sec/batch
# Epoch 10/10 Iteration: 152800 Avg. Training loss: 4.1406 0.3902 sec/batch
# Epoch 10/10 Iteration: 152900 Avg. Training loss: 4.1732 0.3953 sec/batch
# Epoch 10/10 Iteration: 153000 Avg. Training loss: 4.2241 0.3857 sec/batch
# Nearest to more: than, less, better, greater, smaller, a, worse, much,
# Nearest to s: one, u, nine, the, eight, machaut, patents, roxen,
# Nearest to in: at, the, a, and, during, on, but, for,
# Nearest to which: the, and, called, a, usually, in, such, several,
# Nearest to with: but, a, in, disorganised, and, the, at, laboriously,
# Nearest to will: can, must, should, would, is, cannot, may, does,
# Nearest to there: they, it, are, some, many, is, only, has,
# Nearest to four: three, five, six, one, two, seven, eight, zero,
# Nearest to award: awards, best, grammy, prize, medal, winning, sciences, academy,
# Nearest to governor: daimyo, minister, legislative, wadsworth, lieutenant, delegate, incumbent, government,
# Nearest to marriage: murder, anne, child, married, parent, overwork, son, raincoat,
# Nearest to instance: example, reasons, purposes, see, purpose, disambiguation, decades, igf,
# Nearest to ocean: pacific, microwave, atlantic, oceans, indian, intelsat, islands, cables,
# Nearest to professional: indoor, transitioned, recommendations, ups, basketball, team, sporting, affiliated,
# Nearest to animals: humans, human, organisms, species, mammals, recombination, shingles, chromosomes,
# Nearest to accepted: regarded, respected, recognised, universally, considered, frequently, albertus, known,
# Epoch 10/10 Iteration: 153100 Avg. Training loss: 4.2446 35.8043 sec/batch
# Epoch 10/10 Iteration: 153200 Avg. Training loss: 4.2327 0.2901 sec/batch
# Epoch 10/10 Iteration: 153300 Avg. Training loss: 4.2451 0.2873 sec/batch
# Epoch 10/10 Iteration: 153400 Avg. Training loss: 4.2529 0.2990 sec/batch
# Epoch 10/10 Iteration: 153500 Avg. Training loss: 4.2834 0.2953 sec/batch
# Epoch 10/10 Iteration: 153600 Avg. Training loss: 4.2200 0.2986 sec/batch
# Epoch 10/10 Iteration: 153700 Avg. Training loss: 4.1559 0.3205 sec/batch
# Epoch 10/10 Iteration: 153800 Avg. Training loss: 4.2412 0.2988 sec/batch
# Epoch 10/10 Iteration: 153900 Avg. Training loss: 4.2651 0.2915 sec/batch
# Epoch 10/10 Iteration: 154000 Avg. Training loss: 4.2302 0.2899 sec/batch
# Nearest to more: than, less, better, greater, smaller, a, much, efficient,
# Nearest to s: one, nine, the, eight, u, his, saw, roxen,
# Nearest to in: at, the, and, a, during, but, by, on,
# Nearest to which: the, and, called, usually, several, in, such, a,
# Nearest to with: a, in, disorganised, and, but, associated, heinemann, laboriously,
# Nearest to will: can, must, should, would, cannot, is, may, are,
# Nearest to there: it, they, are, some, is, many, only, this,
# Nearest to four: three, five, six, one, two, seven, eight, zero,
# Nearest to award: awards, best, grammy, prize, medal, winning, academy, sciences,
# Nearest to governor: daimyo, minister, legislative, lieutenant, government, incumbent, wadsworth, delegate,
# Nearest to marriage: murder, anne, child, married, overwork, son, parent, raincoat,
# Nearest to instance: example, reasons, purposes, see, disambiguation, purpose, decades, seditious,
# Nearest to ocean: pacific, microwave, atlantic, indian, oceans, intelsat, islands, cables,
# Nearest to professional: transitioned, recommendations, indoor, ups, team, native, affiliated, quarters,
# Nearest to animals: humans, human, species, organisms, mammals, physiology, chromosomes, infection,
# Nearest to accepted: regarded, respected, considered, universally, known, agreed, understood, frequently,
# Epoch 10/10 Iteration: 154100 Avg. Training loss: 4.2224 0.2987 sec/batch
# Epoch 10/10 Iteration: 154200 Avg. Training loss: 4.2097 0.2902 sec/batch
# Epoch 10/10 Iteration: 154300 Avg. Training loss: 4.2221 0.2786 sec/batch
# Epoch 10/10 Iteration: 154400 Avg. Training loss: 4.2572 0.2755 sec/batch
# Epoch 10/10 Iteration: 154500 Avg. Training loss: 4.2043 0.2843 sec/batch
# Epoch 10/10 Iteration: 154600 Avg. Training loss: 4.2537 0.2842 sec/batch
# Epoch 10/10 Iteration: 154700 Avg. Training loss: 4.2569 0.2826 sec/batch
# Epoch 10/10 Iteration: 154800 Avg. Training loss: 4.2250 0.2819 sec/batch
# Epoch 10/10 Iteration: 154900 Avg. Training loss: 4.1168 0.2895 sec/batch
# Epoch 10/10 Iteration: 155000 Avg. Training loss: 4.2372 0.2850 sec/batch
# Nearest to more: than, less, greater, smaller, better, a, some, much,
# Nearest to s: one, nine, eight, the, u, six, roxen, saw,
# Nearest to in: the, and, at, a, during, but, one, on,
# Nearest to which: the, and, called, usually, several, in, consisting, a,
# Nearest to with: in, disorganised, a, and, but, the, plough, between,
# Nearest to will: can, must, should, would, cannot, is, may, are,
# Nearest to there: they, are, it, some, many, is, only, can,
# Nearest to four: three, five, six, one, two, seven, eight, zero,
# Nearest to award: awards, best, grammy, prize, medal, winning, academy, sciences,
# Nearest to governor: daimyo, minister, lieutenant, legislative, wadsworth, government, delegate, incumbent,
# Nearest to marriage: murder, anne, married, child, son, overwork, raincoat, parent,
# Nearest to instance: example, reasons, purposes, see, disambiguation, purpose, decades, seditious,
# Nearest to ocean: pacific, indian, microwave, oceans, atlantic, intelsat, islands, cables,
# Nearest to professional: transitioned, indoor, native, basketball, team, recommendations, ups, quarters,
# Nearest to animals: humans, human, species, mammals, organisms, recombination, chromosomes, physiology,
# Nearest to accepted: regarded, respected, universally, considered, agreed, known, frequently, recognised,
# Epoch 10/10 Iteration: 155100 Avg. Training loss: 4.2256 0.3018 sec/batch
# Epoch 10/10 Iteration: 155200 Avg. Training loss: 4.2326 0.2873 sec/batch
# Epoch 10/10 Iteration: 155300 Avg. Training loss: 4.1680 0.2772 sec/batch
# Epoch 10/10 Iteration: 155400 Avg. Training loss: 4.1993 0.2878 sec/batch
# Epoch 10/10 Iteration: 155500 Avg. Training loss: 4.2044 0.2869 sec/batch
# Epoch 10/10 Iteration: 155600 Avg. Training loss: 4.2714 0.2764 sec/batch
# Epoch 10/10 Iteration: 155700 Avg. Training loss: 4.1690 0.2824 sec/batch
# Epoch 10/10 Iteration: 155800 Avg. Training loss: 3.8540 0.2855 sec/batch
# Epoch 10/10 Iteration: 155900 Avg. Training loss: 3.9375 0.2848 sec/batch
# Epoch 10/10 Iteration: 156000 Avg. Training loss: 4.1025 0.2781 sec/batch
# Nearest to more: than, less, greater, better, smaller, much, a, efficient,
# Nearest to s: one, the, u, eight, nine, and, his, roxen,
# Nearest to in: the, at, and, a, one, during, on, two,
# Nearest to which: the, called, several, and, usually, consisting, in, such,
# Nearest to with: a, in, but, alexandr, disorganised, and, dowleh, the,
# Nearest to will: can, must, should, would, is, cannot, may, are,
# Nearest to there: they, it, are, some, many, is, only, has,
# Nearest to four: three, five, six, two, one, seven, eight, zero,
# Nearest to award: awards, best, grammy, prize, winning, medal, academy, honorary,
# Nearest to governor: daimyo, minister, wadsworth, lieutenant, legislative, bayh, delegate, boroughs,
# Nearest to marriage: anne, married, murder, son, child, parent, overwork, raincoat,
# Nearest to instance: example, reasons, purposes, purpose, disambiguation, see, decades, seditious,
# Nearest to ocean: pacific, microwave, atlantic, indian, oceans, islands, intelsat, cables,
# Nearest to professional: native, basketball, indoor, transitioned, football, cronin, recommendations, team,
# Nearest to animals: humans, species, human, organisms, mammals, recombination, chromosomes, genera,
# Nearest to accepted: regarded, respected, universally, known, considered, frequently, recognised, agreed,
# Epoch 10/10 Iteration: 156100 Avg. Training loss: 3.9917 0.2934 sec/batch
# Epoch 10/10 Iteration: 156200 Avg. Training loss: 4.1584 0.2907 sec/batch
# Epoch 10/10 Iteration: 156300 Avg. Training loss: 4.2381 0.2955 sec/batch
# Epoch 10/10 Iteration: 156400 Avg. Training loss: 4.1898 0.2846 sec/batch
# Epoch 10/10 Iteration: 156500 Avg. Training loss: 4.2490 0.2825 sec/batch
# Epoch 10/10 Iteration: 156600 Avg. Training loss: 4.1907 0.2913 sec/batch
# Epoch 10/10 Iteration: 156700 Avg. Training loss: 4.2478 0.2839 sec/batch
# Epoch 10/10 Iteration: 156800 Avg. Training loss: 4.2559 0.2876 sec/batch
# Epoch 10/10 Iteration: 156900 Avg. Training loss: 4.2849 0.2841 sec/batch
# Epoch 10/10 Iteration: 157000 Avg. Training loss: 4.2564 0.2832 sec/batch
# Nearest to more: than, less, better, smaller, greater, efficient, much, a,
# Nearest to s: one, the, eight, nine, u, and, six, early,
# Nearest to in: the, at, and, a, during, on, one, of,
# Nearest to which: called, the, several, and, consisting, usually, in, based,
# Nearest to with: a, in, disorganised, and, the, kamakura, when, eigenfunctions,
# Nearest to will: can, should, must, would, is, cannot, may, does,
# Nearest to there: are, they, it, some, many, is, has, this,
# Nearest to four: three, five, six, one, two, seven, eight, zero,
# Nearest to award: awards, best, grammy, winning, academy, prize, medal, sciences,
# Nearest to governor: daimyo, wadsworth, lieutenant, minister, bayh, legislative, delegate, incumbent,
# Nearest to marriage: married, murder, anne, son, child, daughter, parent, overwork,
# Nearest to instance: example, reasons, purposes, purpose, see, disambiguation, decades, seditious,
# Nearest to ocean: pacific, indian, atlantic, oceans, microwave, islands, intelsat, cables,
# Nearest to professional: native, indoor, transitioned, basketball, team, recommendations, cronin, football,
# Nearest to animals: humans, human, organisms, mammals, species, recombination, topological, chromosomes,
# Nearest to accepted: regarded, respected, universally, known, agreed, considered, recognised, frequently,
# Epoch 10/10 Iteration: 157100 Avg. Training loss: 4.2561 0.2945 sec/batch
# Epoch 10/10 Iteration: 157200 Avg. Training loss: 4.2098 0.2880 sec/batch
# Epoch 10/10 Iteration: 157300 Avg. Training loss: 4.0780 0.2808 sec/batch
# Epoch 10/10 Iteration: 157400 Avg. Training loss: 4.2264 0.2784 sec/batch
# Epoch 10/10 Iteration: 157500 Avg. Training loss: 4.2577 0.2851 sec/batch
# Epoch 10/10 Iteration: 157600 Avg. Training loss: 4.1966 0.2867 sec/batch
# Epoch 10/10 Iteration: 157700 Avg. Training loss: 4.2194 0.2834 sec/batch
# Epoch 10/10 Iteration: 157800 Avg. Training loss: 4.1903 0.2891 sec/batch
# Epoch 10/10 Iteration: 157900 Avg. Training loss: 4.2645 0.2916 sec/batch
# Epoch 10/10 Iteration: 158000 Avg. Training loss: 4.2663 0.2833 sec/batch
# Nearest to more: than, less, better, smaller, greater, a, much, most,
# Nearest to s: one, the, u, eight, and, nine, a, machaut,
# Nearest to in: the, at, a, and, on, an, by, for,
# Nearest to which: the, called, and, several, a, in, consisting, usually,
# Nearest to with: a, in, and, the, but, when, freshwater, macrolides,
# Nearest to will: can, must, would, should, is, cannot, are, may,
# Nearest to there: are, it, they, is, some, many, these, can,
# Nearest to four: three, six, five, one, two, seven, eight, zero,
# Nearest to award: awards, best, grammy, winning, prize, medal, academy, nomination,
# Nearest to governor: daimyo, lieutenant, wadsworth, legislative, bayh, minister, incumbent, delegate,
# Nearest to marriage: murder, son, married, child, raincoat, anne, daughter, overwork,
# Nearest to instance: example, reasons, purposes, purpose, see, disambiguation, decades, haute,
# Nearest to ocean: pacific, atlantic, oceans, microwave, indian, islands, intelsat, equator,
# Nearest to professional: native, transitioned, indoor, recommendations, hitting, basketball, team, affiliated,
# Nearest to animals: humans, human, species, mammals, organisms, topological, recombination, physiology,
# Nearest to accepted: regarded, respected, agreed, universally, considered, known, recognised, conserved,
# Epoch 10/10 Iteration: 158100 Avg. Training loss: 4.2065 0.2901 sec/batch
# Epoch 10/10 Iteration: 158200 Avg. Training loss: 4.2297 0.2846 sec/batch
# Epoch 10/10 Iteration: 158300 Avg. Training loss: 4.0672 0.2845 sec/batch
# Epoch 10/10 Iteration: 158400 Avg. Training loss: 4.0476 0.2883 sec/batch
# Epoch 10/10 Iteration: 158500 Avg. Training loss: 4.2058 0.2808 sec/batch
# Epoch 10/10 Iteration: 158600 Avg. Training loss: 4.2057 0.2811 sec/batch
# Epoch 10/10 Iteration: 158700 Avg. Training loss: 4.1510 0.2863 sec/batch
# Epoch 10/10 Iteration: 158800 Avg. Training loss: 4.1186 0.2808 sec/batch
# Epoch 10/10 Iteration: 158900 Avg. Training loss: 4.1933 0.2849 sec/batch
# Epoch 10/10 Iteration: 159000 Avg. Training loss: 4.2481 0.2838 sec/batch
# Nearest to more: than, less, better, smaller, greater, a, most, much,
# Nearest to s: one, u, the, eight, nine, and, machaut, six,
# Nearest to in: the, at, a, and, on, one, by, of,
# Nearest to which: called, the, and, several, is, usually, a, consisting,
# Nearest to with: a, in, and, the, but, an, when, which,
# Nearest to will: can, must, should, would, is, cannot, are, may,
# Nearest to there: it, are, they, is, some, many, this, these,
# Nearest to four: five, six, three, one, two, seven, eight, zero,
# Nearest to award: awards, best, grammy, academy, nomination, medal, winning, prize,
# Nearest to governor: daimyo, lieutenant, legislative, minister, delegate, wadsworth, bayh, boroughs,
# Nearest to marriage: murder, child, son, married, anne, parent, sex, jurisdictions,
# Nearest to instance: example, reasons, purposes, see, disambiguation, purpose, decades, pandit,
# Nearest to ocean: pacific, atlantic, microwave, oceans, indian, islands, intelsat, cables,
# Nearest to professional: native, basketball, indoor, students, hitting, degrees, transitioned, cronin,
# Nearest to animals: humans, human, mammals, species, organisms, physiology, topological, chromosomes,
# Nearest to accepted: regarded, respected, considered, agreed, universally, known, recognised, conserved,
# Epoch 10/10 Iteration: 159100 Avg. Training loss: 4.2368 0.2908 sec/batch
# Epoch 10/10 Iteration: 159200 Avg. Training loss: 4.1580 0.2892 sec/batch
# Epoch 10/10 Iteration: 159300 Avg. Training loss: 4.1691 0.2858 sec/batch
# Epoch 10/10 Iteration: 159400 Avg. Training loss: 4.1995 0.2902 sec/batch
# Epoch 10/10 Iteration: 159500 Avg. Training loss: 4.2036 0.2828 sec/batch
# Epoch 10/10 Iteration: 159600 Avg. Training loss: 4.2574 0.2843 sec/batch
# Epoch 10/10 Iteration: 159700 Avg. Training loss: 4.3067 0.2872 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
# Out:
# /Users/nikhil/anaconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /Users/nikhil/anaconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
